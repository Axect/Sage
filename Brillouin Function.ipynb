# %%
var('y j')
B(y) = (1 + 1/(2*j))*coth((1+1/(2*j))*y) - 1/(2*j)*coth(y/(2*j))

# %%
C1(y) = B.subs(j==1/2)
C2(y) = B.subs(j==3/2)
C3(y) = B.subs(j==5/2)
C4(y) = B.subs(j==7/2)

# %%
plot(C1(y), 0, 5) + plot(C2(y), 0, 5) + plot(C3(y), 0, 5) + plot(C4(y), 0, 5)
# Out:
# Graphics object consisting of 4 graphics primitives
